# %% [markdown]
# # Assignment: Data Wrangling and Exploratory Data Analysis
# ## Do Q1 and Q2, and one other question.
# `! git clone https://www.github.com/ytkidanu/assignment2`

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#  <font color='green'> This paper focuses on the aspect of data cleaning known as "data tidying." The paper argues that tidy datasets are more manageable and that a consistent data structure simplifies the process of dealing with a variety of messy datasets using a small set of tools. </font>
#
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#
#    <font color='green'> It is intended to provide a standardized way of organizing data within a dataset with the goal of making data cleaning more efficient and reducing the need to start from scratch or reinvent the process for every analysis. </font>
#
#
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#
# <font color='green'> The first sentance refers to how every tidy dataset shares a common structure, much like how there are common charecteristics that allow us to identify a group of people as a familiy. However, just as every family has its unique traits that distinguish it from others, each messy dataset has its own distinctive challenges and complexities.
#
# The second Sentance, I think that it is saying something along the lines of how in the context of a particular dataset, it's often clear what the rows and columns represented. However, it's challenging to come up with a wider, more abstract deifnition for what constitutes a variable or an observation that can be applied to any dataset. </font>
#
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#
#
#    <font color='green'> Values = are the individual data points in a dataset, typically numbers for quantitative data or strings for qualitative data.
#
#    <font color='green'> Variables =  variable is a characteristic that can vary from one unit of observation to another. It represents an attribute that is being measured or observed. (Column) </font>
#
#    Observation = An observation is a single instance or entry in a datase. (row). </font>
#
#   5. How is "Tidy Data" defined in section 2.3?
#
#
# <font color='green'>  It adheres to three principles: First, each variable is allocated its own column within the dataset. Second, every observation is represented as a distinct row, capturing individual data points. Finally, tables are formed to group different types of observational units.
#
# Fixed variables are the parts of the study we plan ahead and know about beforehand. Measured variables are the things we actually observe during the study. The Journal suggests to put the planned, fixed variables first when organizing data, followed by the ones we measure. This helps keep related things together and makes it easier to understand.
#  </font>
#
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#
# <font color='green'>
# 1. Column headers are values, not variable names.
# 2. Multiple variables are stored in one column.
# 3. Variables are stored in both rows and columns.
# 4. Multiple types of observational units are stored in the same table.
# 5. A single observational unit is stored in multiple tables.
#
# <font color='green'> Instead of having distinct columns for variables like income and religion, the actual income categories serve as column headers. The income categories and the frequency of occurrences are both contained in the same column. </font>
#
# Melting a dataset involves transforming it from a wide format, where variables are spread across columns, into a long format, where each variable is a column, and each observation forms a row.  It typically involves converting column to rows. </font>
#
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#
#
#  <font color='green'> In table 11, The columns d1 to d31 represent days of the month, and each cell contains a temperature value for that day. This format breaks the tidy data principle where each variable should have its own column. </font>
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?
#
# <font color='green'> If tools are designed to work specifically with tidy data, then the effectiveness of tidy data is reliant on those tools. However, developing new tools id hard if the data structures themselves are not already defined.
#
# Wickham hopes we make improvements in how we design tools for working with data. He believes it's important to consider how people think and work with data, bringing in ideas from areas like human factors and user-centered design. He also thinks we should explore different ways of organizing data, like handling values stored in multidimensional arrays, to make our tools more efficient with memory usage and performance. In doing this, he hopes we can overcome challenges and find better ways of organizing data.
# </font>

# %%
! git clone https://www.github.com/ytkidanu/assignment2
# %ls assignment2
abnb_path = './assignment2/data/airbnb_hw.csv'
# Out:
# Cloning into 'assignment2'...
# ...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 36 (delta 8), reused 5 (delta 5), pack-reused 24
# Receiving objects: 100% (36/36), 5.47 MiB | 12.41 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# assignment2.ipynb  data/  tidy_data.pdf

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?) Total Missing: 0
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.
#
# I used Pandas to read the 'sharks.csv' file into a DataFrame named sharks_df. Then I explored the unique values and their occurrences in the 'Type' column to understand the distribution. I checked the data type of the 'Type' column before making any changes. I tried to converted the 'Type' column to strings using the astype method ( I don't think this worked ).  When I looked at the demensions of the graph, then compared it to the count after I coerced the row to be a string, I saw that there was a difference of 5 between the occurance count and the dimmensions. So, I created a new column named 'type_NA' to represent missing values in the 'Type' column. then I printed the total count of missing values in the 'Type' column, which was now 0.
#
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
#
# Maybe I imported the wrong data, but there was no WhetherDefendantWasReleasedPretrial variable in my data set. There was one callled released but I didnt want to assume. But what I would have done is change the name of the variable to somethign more concise( like pretrial_release). If the type of pretrial_release is supposed to be a str,then i would coerce the column to be str, Then I check all the unique vaules of pretrial_release to check to see how null could have been denoted. Then I create a dummy variable to hold the missing values where I replace them with np.nan.
#
#
#
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)
#
# I would rename ImposedSentenceAllChargeInContactEvent, then I'd check for missing variables, and then handle the missing valued by replacing it with a specific value. I would check to make sure it correctly filled in missing values, maybe look at SentenceTypeAllChargesAtConvictionInContactEvent to see what I need to replace null with ( like Not convicted). and then cross tabulate to compare the variables( maybe optional).

# %%
import numpy as np # Import the numpy package into your workspace
import pandas as pd  # Import the pandas package into your workspace

airbnb_df = pd.read_csv('./assignment2/data/airbnb_hw.csv', low_memory=False)
var = 'Price'
print(airbnb_df.shape, '\n') # List the dimensions of df
#print(airbnb_df.dtypes, '\n') # The types of the variables; `object` is a bad sign
airbnb_df.head()

specific_row = airbnb_df[
    (airbnb_df['Host Id'] == 8730) &
    (airbnb_df['Host Since'] == '2/27/2009') &
    (airbnb_df['Property Type'] == 'Condominium')  # Adjust based on your criteria
]

# Print the specific row
print(specific_row)

#airbnb_df[var].hist(bins=50)
airbnb_df['Price_nan'] = airbnb_df[var].isnull()
#print('After coercion: \n', airbnb_df[var].describe(),'\n') # Describe the numeric variable
#airbnb_df[var].hist(bins = 50) # Histogram of the variable values
#airbnb_df['var'].fillna(airbnb_df['var'].mean(), inplace=True)
#print(airbnb_df['Price'].unique(), '\n')

#print("Before cleaning:")
#print(airbnb_df['Price'])
airbnb_df['Price'] = airbnb_df['Price'].str.replace(',', '').astype(float)
#print(airbnb_df['Price'])
#specific_row = airbnb_df[
 #   (airbnb_df['Host Id'] == 8730) &
 #   (airbnb_df['Host Since'] == '2/27/2009') &
 #   (airbnb_df['Property Type'] == 'Condominium')  # Adjust based on your criteria
#]
print('Total Missings: \n', sum(airbnb_df[var+'_nan']),'\n') # There are 0

# Print the specific row
print(specific_row)

print(airbnb_df.shape, '\n')
# Out:
# (30478, 13)
#
#      Host Id Host Since                   Name Neighbourhood  Property Type  \
# 101     8730  2/27/2009  Comfort & Convenience      Manhattan   Condominium
#
#      Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 101                       100.0  Entire home/apt  10003.0   6.0
#
#      Number of Records  Number Of Reviews  Price  Review Scores Rating
# 101                  1                  4  1,990                 100.0
# Total Missings:
#  0
#
#      Host Id Host Since                   Name Neighbourhood  Property Type  \
# 101     8730  2/27/2009  Comfort & Convenience      Manhattan   Condominium
#
#      Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 101                       100.0  Entire home/apt  10003.0   6.0
#
#      Number of Records  Number Of Reviews  Price  Review Scores Rating
# 101                  1                  4  1,990                 100.0
# (30478, 14)

# %%
from numpy.lib.twodim_base import vander
import numpy as np # Import the numpy package into your workspace
import pandas as pd  # Import the pandas package into your workspace

sharks_df = pd.read_csv('./assignment2/data/sharks.csv', low_memory=False)
var = 'Type'

#sharks_df.head()

#print(sharks_df.shape, '\n') # List the dimensions of df 6462#
#print(sharks_df.dtypes, '\n') # The types of the variables; `object` is a bad sign
#print(sharks_df.columns.tolist(), '\n') # First five column names

##sharks_df #preview the data
#types_column = sharks_df[var]

#print(types_column) # looked at column
#sharks_df[var].unique() # then i looked at every uniqur possible answer for this column

sharks_df[var].value_counts() # looked at occurence 6457, so now i know there are missing values... i think

print('Before coercion: \n', sharks_df[var].describe(),'\n') # seen as object
#sharks_df[var].hist(bins=50)

sharks_df[var] = sharks_df[var].astype(str)


print('After coercion: \n', sharks_df[var].describe(),'\n') # Describe the numeric variable
sharks_df[var].hist(bins = 50) # Histogram of the variable values
sharks_df[var].value_counts() # now i can confirm that there are 5 Nan
sharks_df['type_NA'] = sharks_df[var].isnull() # Create a type missing dummy; long tail
print(" Total Missing")
print(sum(sharks_df['type_NA']),'\n') # 0 missing
#print('Total Missings: \n', sum(sharks_df[var+'_nan']),'\n') # How many missing values are there?
# Out:
# Before coercion:
#  count           6457
# unique            12
# top       Unprovoked
# freq            4716
# Name: Type, dtype: object
#
# After coercion:
#  count           6462
# unique            13
# top       Unprovoked
# freq            4716
# Name: Type, dtype: object
#
#  Total Missing
# 0

# %%
! git clone https://www.github.com/ytkidanu/visualization
# Out:
# Cloning into 'visualization'...
# ...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (13/13), 2.17 MiB | 8.38 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
from numpy.lib.twodim_base import vander
import numpy as np # Import the numpy package into your workspace
import pandas as pd  # Import the pandas package into your workspace

df = pd.read_csv('./visualization/data/pretrial_data.csv', low_memory=False)
var = 'WhetherDefendantWasReleasedPretrial'

#types_column = sharks_df[var]

#print(types_column) # looked at column

#print(df.shape, '\n') # List the dimensions of df
#print(df.dtypes, '\n') # The types of the variables; `object` is a bad sign
#print(sharks_df.columns.tolist(), '\n')
#df.head()
#df = df.rename(columns = {'WhetherDefendantWasReleasedPretrial':'released_pretrial'}) # Rename variables
#print(sharks_df.columns.tolist(), '\n')

#df['released_pretrial_missing'] = df['released_pretrial'].isnull().astype(int)

#unique_values = df['released_pretrial'].unique()
#print(unique_values)
#df['released_pretrial'] = df['released_pretrial'].replace('', np.nan)
# Out:
# ['index', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Unnamed: 9', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Un
# ...

# %% [markdown]
# **Q3.** This question provides some practice doing exploratory data analysis and visualization.
#
# The "relevant" variables for this question are:
#   - `level` - Level of institution (4-year, 2-year)
#   - `aid_value` - The average amount of student aid going to undergraduate recipients
#   - `control` - Public, Private not-for-profit, Private for-profit
#   - `grad_100_value` - percentage of first-time, full-time, degree-seeking undergraduates who complete a degree or certificate program within 100 percent of expected time (bachelor's-seeking group at 4-year institutions)
#
# 1. Load the `./data/college_completion.csv` data with Pandas.
# 2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
# 3. Cross tabulate `control` and `level`. Describe the patterns you see.
# 4. For `grad_100_value`, create a histogram, kernel density plot, boxplot, and statistical description.
# 5. For `grad_100_value`, create a grouped kernel density plot by `control` and by `level`. Describe what you see. Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `grad_100_value` by `level` and `control`. Which institutions appear to have the best graduation rates?
# 6. Create a new variable, `df['levelXcontrol']=df['level']+', '+df['control']` that interacts level and control. Make a grouped kernel density plot. Which institutions appear to have the best graduation rates?
# 7. Make a kernel density plot of `aid_value`. Notice that your graph is "bi-modal", having two little peaks that represent locally most common values. Now group your graph by `level` and `control`. What explains the bi-modal nature of the graph? Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `aid_value` by `level` and `control`.
# 8. Make a scatterplot of `grad_100_value` by `aid_value`. Describe what you see. Now make the same plot, grouping by `level` and then `control`. Describe what you see. For which kinds of institutions does aid seem to increase graduation rates?

# %% [markdown]
# **Q4.** This question uses the Airbnb data to practice making visualizations.
#
#   1. Load the `./data/airbnb_hw.csv` data with Pandas. You should have cleaned the `Price` variable in question 2, and you'll need it later for this question.
#
#   2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
#
#   (30478, 14)
#
#
#   3. Cross tabulate `Room Type` and `Property Type`. What patterns do you see in what kinds of rentals are available? For which kinds of properties are private rooms more common than renting the entire property?
#
#   Apartments are the most common available rental. All tents rent our private rooms, none print out shared rooms. It is the same with the hut.
#
#   Private rooms are more dominant in property types such as Apartments, Houses, and Townhouses. It's not very common in vacation-oriented property types like Boats, Cabins, and Lighthouses.
#
#   4. For `Price`, make a histogram, kernel density, box plot, and a statistical description of the variable. Are the data badly scaled? Are there many outliers? Use `log` to transform price into a new variable, `price_log`, and take these steps again.
#
#
#
#   5. Make a scatterplot of `price_log` and `Beds`. Describe what you see. Use `.groupby()` to compute a desciption of `Price` conditional on/grouped by the number of beds. Describe any patterns you see in the average price and standard deviation in prices.
# 5.1 : As price_log increases, so deos the number of rooms, generally, but it's not a storng correlation/obeservation
# 5.2 : The average price generally increases with the number of beds, which is intuitive as larger accommodations tend to be more expensive ( however some exceptions, 12 rooms is much more expensive on average than 13 bedrooms). I do not see a clear pattern in the std between number of rooms and price.
#
#   6. Make a scatterplot of `price_log` and `Beds`, but color the graph by `Room Type` and `Property Type`. What patterns do you see? Compute a description of `Price` conditional on `Room Type` and `Property Type`. Which Room Type and Property Type have the highest prices on average? Which have the highest standard deviation? Does the mean or median appear to be a more reliable estimate of central tendency, and explain why?
#
#
# I see that entire home/apt tend to be more expensive.  While shared room propeties tend to be the cheapest.
#
# Entire home/apt, Other combination has the highest average price at $843.43. Entire home and other have highest deviation. Median, because it will protect you from really big outliers. Like, if you wanted to measure how much the average American makes, the mean would be heavily skewed by the Billionaires in this ocuntry. It would make the average American look like they have way more wealth than they do.
#
#   7. We've looked a bit at this `price_log` and `Beds` scatterplot. Use seaborn to make a `jointplot` with `kind=hex`. Where are the data actually distributed? How does it affect the way you think about the plots in 5 and 6?
# Its mostly concentrated in the center of the y axis, around 4-7. There seems to be more houses that are more expensive than this range than cheaper than the range. This graph made me think of plots in 5 and 6 as the central tendency

# %%
import numpy as np # Import the numpy package into your workspace
import pandas as pd  # Import the pandas package into your workspace
import seaborn as sns # Import Seaborn

#airbnb_df = pd.read_csv('./assignment2/data/airbnb_hw.csv', low_memory=False)
print(airbnb_df.shape, '\n')

#cross_tab = pd.crosstab(df['Room Type'], df['Property Type'])
#print(cross_tab)
#print(airbnb_df['Price'])


airbnb_df['Price_arcsinh'] = np.arcsinh(airbnb_df['Price'])
airbnb_df['Price_arcsinh'].hist(bins=20,grid=False) # Notice all the data at zero that log throws away
#airbnb_df['Price'] = airbnb_df['Price'].str.replace(',', '').astype(float)

#sns.kdeplot(airbnb_df['Price'])
# Out:
# (30478, 14)
# <Axes: >

# %%
sns.kdeplot(airbnb_df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(data=airbnb_df, x='Price')
# Out:
# <Axes: xlabel='Price'>

# %%
description = airbnb_df['Price'].describe()
print(description)
# Out:
# count    30478.000000
# mean       163.589737
# std        197.785454
# min         10.000000
# 25%         80.000000
# 50%        125.000000
# 75%        195.000000
# max      10000.000000
# Name: Price, dtype: float64

# %%
airbnb_df['price_log'] = np.log(airbnb_df['Price'])
#sns.boxplot(data=airbnb_df, x='price_log')
#sns.kdeplot(airbnb_df['price_log'])

#airbnb_df['PriceLog_arcsinh'] = np.arcsinh(airbnb_df['price_log'])
#airbnb_df['PriceLog_arcsinh'].hist(bins=20,grid=False) # Notice all the data at zero that log throws away
#description = airbnb_df['price_log'].describe()
#print(description)

sns.scatterplot(x=airbnb_df['Beds'],y=airbnb_df['price_log'])
#price_stats_by_beds = airbnb_df.groupby('Beds')['Price'].describe()
#price_stats_by_beds = airbnb_df.groupby('Beds')['Price'].std()

#print(price_stats_by_beds)
# Out:
# <Axes: xlabel='Beds', ylabel='price_log'>

# %%
import matplotlib.pyplot as plt
#airbnb_df['Beds'] = pd.to_numeric(airbnb_df['Beds'], errors='coerce')
#airbnb_df['price_log'] = pd.to_numeric(airbnb_df['price_log'], errors='coerce')
#sns.scatterplot(x=airbnb_df['Beds'],y=airbnb_df['price_log'])
this_plot = sns.scatterplot(data=airbnb_df, x='Beds', y='price_log', hue='Room Type', style='Property Type', palette='viridis')
#plt.title('Scatterplot of Price Log vs Beds by Room Type and Property Type')

price_conditional_stats = airbnb_df.groupby(['Room Type', 'Property Type'])['Price'].describe()
print(price_conditional_stats)
# Out:
#                                    count        mean          std    min  \
# Room Type       Property Type
# Entire home/apt Apartment        15669.0  213.224839   218.097834   10.0
#                 Bed & Breakfast     13.0  184.538462   119.814172   85.0
#                 Boat                 7.0  158.428571    51.110524  100.0
#                 Bungalow             4.0  150.750000    46.464144   87.0
#                 Cabin                1.0  250.000000          NaN  250.0
#                 Camper/RV            6.0  114.333333   107.685963   45.0
#                 Condominium         72.0  304.861111   266.197497   80.0
#                 Dorm                 4.0   44.250000    24.060687   30.0
#                 House              752.0  297.263298   468.409428   27.0
#                 Lighthouse           1.0   39.000000          NaN   39.0
#                 Loft               392.0  330.510204   321.519721   55.0
# ...

# %%
this_plot = sns.jointplot( x='Beds', y='price_log', data=airbnb_df)

# %% [markdown]
# **Q5.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?

# %% [markdown]
# **Q6.** Open the `./data/CBO_data.pdf` file. This contains tax data for 2019, explaining where the money comes from that the U.S. Federal Government Spends in terms of taxation on individuals/families and payroll taxes (the amount that your employer pays in taxes on your wages).
#
# For some context, the Federal government ultimately spent about $4.4 trillion in 2019, which was 21% of GDP (the total monetary value of all goods and services produced within the United States). Individual Income Taxes is the amount individuals pay on their wages to the Federal government, Corporate Income Taxes is the taxes individuals pay on capital gains from investment when they sell stock or other financial instruments, Payroll Taxes is the tax your employer pays on your wages, Excises and Customs Duties are taxes on goods or services like sin taxes on cigarettes or alcohol, and Estate and Gift Taxes are taxes paid on transfers of wealth to other people.
#
# 1. Get the Millions of Families and Billions of Dollars data into a .csv file and load it with Pandas.
# 2. Create a bar plot of individual income taxes by income decile. Explain what the graph shows. Why are some values negative?
# 3. Create a bar plot of Total Federal Taxes by income decile. Which deciles are paying net positive amounts, and which are paying net negative amounts?
# 4. Create a stacked bar plot for which Total Federal Taxes is grouped by Individual Income Taxes, Payroll Taxes, Excises and Customs Duties, and Estate and Gift Taxes. How does the share of taxes paid vary across the adjusted income deciles? (Hint: Are these the kind of data you want to melt?)
# 5. Below the Total line for Millions of Families and Billions of Dollars, there are data for the richest of the richest families. Plot this alongside the bars for the deciles above the Total line. Describe your results.
# 6. Get the Percent Distribution data into a .csv file and load it with Pandas. Create a bar graph of Total Federal Taxes by income decile.
# 7. A tax system is progressive if higher-income and wealthier individuals pay more than lower-income and less wealthy individuals, and it is regressive if the opposite is true. Is the U.S. tax system progressive in terms of amount paid? In terms of the percentage of the overall total?
# 8. Do the rich pay enough in taxes? Defend your answer.
